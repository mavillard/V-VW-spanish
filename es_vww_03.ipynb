# %%
from collections import Counter
import pickle

import nltk
from nltk.corpus import stopwords
import pandas as pd

# %%
with open('data/out/clean_stories.pickle', 'rb') as f:
    stories = pickle.load(f)

# %%
len(stories)
# Out:
# 98

# %%
N = 25

# %%
all_words = [w for story in stories for w in story['text'].split()]

# %%
len(all_words)
# Out:
# 1681069

# %%
all_counter = Counter(all_words)

# %%
all_counter.most_common(N)
# Out:
# [('ojos', 20383),
#  ('cabeza', 10363),
#  ('mano', 10299),
#  ('puerta', 9683),
#  ('manos', 9043),
#  ('mirada', 8763),
#  ('cuerpo', 8184),
#  ('casa', 8039),
#  ('voz', 7857),
#  ('tiempo', 7383),
#  ('sangre', 7352),
#  ('habitacion', 7132),
#  ('sonrisa', 6881),
#  ('rostro', 6775),
#  ('vida', 5945),
#  ('frente', 5899),
#  ('padre', 5755),
#  ('labios', 5737),
#  ('brazos', 5716),
#  ('cama', 5368),
#  ('madre', 5092),
#  ('gracias', 4750),
#  ('vampiro', 4515),
#  ('suelo', 4513),
#  ('cuello', 4363)]

# %%
v_words = [w for story in stories for w in story['text'].split() if story['category'] == 'VAMPIROS (HISTORIAS EN ESPANOL)']

# %%
len(v_words)
# Out:
# 1005091

# %%
v_counter = Counter(v_words)

# %%
v_counter.most_common(N)
# Out:
# [('ojos', 12339),
#  ('cabeza', 6300),
#  ('mano', 6268),
#  ('puerta', 6091),
#  ('sangre', 5809),
#  ('mirada', 5677),
#  ('manos', 5509),
#  ('cuerpo', 4938),
#  ('tiempo', 4858),
#  ('voz', 4807),
#  ('casa', 4667),
#  ('rostro', 4510),
#  ('habitacion', 4351),
#  ('sonrisa', 4257),
#  ('vampiro', 4112),
#  ('vida', 3675),
#  ('frente', 3604),
#  ('labios', 3320),
#  ('padre', 3291),
#  ('vampiros', 3289),
#  ('cama', 3278),
#  ('brazos', 3056),
#  ('madre', 2962),
#  ('gracias', 2916),
#  ('cuello', 2755)]

# %%
ww_words = [w for story in stories for w in story['text'].split() if story['category'] == 'HOMBRES LOBO (HISTORIAS EN ESPAÑOL)']

# %%
len(ww_words)
# Out:
# 675978

# %%
ww_counter = Counter(ww_words)

# %%
ww_counter.most_common(N)
# Out:
# [('ojos', 8044),
#  ('cabeza', 4063),
#  ('mano', 4031),
#  ('puerta', 3592),
#  ('manos', 3534),
#  ('casa', 3372),
#  ('cuerpo', 3246),
#  ('mirada', 3086),
#  ('voz', 3050),
#  ('habitacion', 2781),
#  ('brazos', 2660),
#  ('sonrisa', 2624),
#  ('tiempo', 2525),
#  ('lobo', 2502),
#  ('padre', 2464),
#  ('labios', 2417),
#  ('manada', 2371),
#  ('luna', 2331),
#  ('frente', 2295),
#  ('vida', 2270),
#  ('rostro', 2265),
#  ('madre', 2130),
#  ('cama', 2090),
#  ('suelo', 1984),
#  ('chicos', 1865)]

# %%
union_top_words = set(w for w, f in v_counter.most_common(N)).union(w for w, f in ww_counter.most_common(N))

# %%
top_df = pd.DataFrame(
    data=[[all_counter[w], v_counter[w], ww_counter[w]] for w in sorted(union_top_words)],
    index=sorted(union_top_words),
    columns=['Freq. total', 'Freq. vampires', 'Freq. werewolves']
)

# %%
top_df.shape
# Out:
# (30, 3)

# %%
top_df.sort_values('Freq. total', ascending=False)
# Out:
#             Freq. total  Freq. vampires  Freq. werewolves
# ojos              20383           12339              8044
# cabeza            10363            6300              4063
# mano              10299            6268              4031
# puerta             9683            6091              3592
# manos              9043            5509              3534
# mirada             8763            5677              3086
# cuerpo             8184            4938              3246
# casa               8039            4667              3372
# voz                7857            4807              3050
# tiempo             7383            4858              2525
# sangre             7352            5809              1543
# habitacion         7132            4351              2781
# sonrisa            6881            4257              2624
# rostro             6775            4510              2265
# vida               5945            3675              2270
# frente             5899            3604              2295
# padre              5755            3291              2464
# labios             5737            3320              2417
# brazos             5716            3056              2660
# cama               5368            3278              2090
# madre              5092            2962              2130
# gracias            4750            2916              1834
# vampiro            4515            4112               403
# suelo              4513            2529              1984
# cuello             4363            2755              1608
# vampiros           3747            3289               458
# lobo               3362             860              2502
# chicos             2898            1033              1865
# manada             2748             377              2371
# luna               2710             379              2331

# %%
top_df.sort_values('Freq. vampires', ascending=False)
# Out:
#             Freq. total  Freq. vampires  Freq. werewolves
# ojos              20383           12339              8044
# cabeza            10363            6300              4063
# mano              10299            6268              4031
# puerta             9683            6091              3592
# sangre             7352            5809              1543
# mirada             8763            5677              3086
# manos              9043            5509              3534
# cuerpo             8184            4938              3246
# tiempo             7383            4858              2525
# voz                7857            4807              3050
# casa               8039            4667              3372
# rostro             6775            4510              2265
# habitacion         7132            4351              2781
# sonrisa            6881            4257              2624
# vampiro            4515            4112               403
# vida               5945            3675              2270
# frente             5899            3604              2295
# labios             5737            3320              2417
# padre              5755            3291              2464
# vampiros           3747            3289               458
# cama               5368            3278              2090
# brazos             5716            3056              2660
# madre              5092            2962              2130
# gracias            4750            2916              1834
# cuello             4363            2755              1608
# suelo              4513            2529              1984
# chicos             2898            1033              1865
# lobo               3362             860              2502
# luna               2710             379              2331
# manada             2748             377              2371

# %%
top_df.sort_values('Freq. werewolves', ascending=False)
# Out:
#             Freq. total  Freq. vampires  Freq. werewolves
# ojos              20383           12339              8044
# cabeza            10363            6300              4063
# mano              10299            6268              4031
# puerta             9683            6091              3592
# manos              9043            5509              3534
# casa               8039            4667              3372
# cuerpo             8184            4938              3246
# mirada             8763            5677              3086
# voz                7857            4807              3050
# habitacion         7132            4351              2781
# brazos             5716            3056              2660
# sonrisa            6881            4257              2624
# tiempo             7383            4858              2525
# lobo               3362             860              2502
# padre              5755            3291              2464
# labios             5737            3320              2417
# manada             2748             377              2371
# luna               2710             379              2331
# frente             5899            3604              2295
# vida               5945            3675              2270
# rostro             6775            4510              2265
# madre              5092            2962              2130
# cama               5368            3278              2090
# suelo              4513            2529              1984
# chicos             2898            1033              1865
# gracias            4750            2916              1834
# cuello             4363            2755              1608
# sangre             7352            5809              1543
# vampiros           3747            3289               458
# vampiro            4515            4112               403

# %% [markdown]
# “Topics are usually characterized in the form of noun phrases” [1].
#
# **References**
# <br>
# [1] Xie, Z., P. C. Nelson, W. Xiao, and T. M. Tirpak. 2004. “Using Noun Phrase Centrality to Identify Topics for Extraction Based Summaries.” In *Proceedings of the IASTED International Conference on Knowledge Sharing and Collaborative Engineering*. US Virgin Islands: ACTA Press. http://www.actapress.com/Abstract.aspx?paperId=17241.
